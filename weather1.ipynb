# %%
from datetime import datetime, timedelta
import pandas as pd
import urllib.request
import json

# %%
api_key = "98716afd22b34d428b2145552231708"

# %%
def retrieve_hist_data(api_key, location_list, start_date, end_date, frequency, location_label=False, export_csv=True,
                       store_df=False, response_cache_path=None):
    result_list = []
    for location in location_list:
        print('\n\nRetrieving weather data for ' + location + '\n\n')
        df_this_city = retrieve_this_location(api_key, location, start_date, end_date, frequency, response_cache_path)

        if (location_label == True):
            # add city name as prefix to the colnames
            df_this_city = df_this_city.add_prefix(location + '_')
            df_this_city.columns.values[0] = 'date_time'

        if (export_csv == True):
            df_this_city.to_csv('./' + location + '.csv', header=True, index=False)
            print('\n\nexport ' + location + ' completed!\n\n')

        if (store_df == True):
            # save result as object in the work space
            result_list.append(df_this_city)

    return (result_list)

# %%
def retrieve_this_location(api_key, location, start_date, end_date, frequency, response_cache_path):
    start_time = datetime.now()

    # create list of first day of month for range between start and end dates non-inclusive (open)
    list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
    # convert to Series and add start_date at beginning
    list_mon_begin = pd.concat([pd.Series(pd.to_datetime(start_date)), pd.Series(list_mon_begin)], ignore_index=True)

    # create list of month end dates for range between start and end dates non-inclusive (open)
    list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
    # convert to Series and add end_date at end
    list_mon_end = pd.concat([pd.Series(list_mon_end), pd.Series(pd.to_datetime(end_date))], ignore_index=True)

    # count number of months to be retrieved
    total_months = len(list_mon_begin)

    # initialize df_hist to store return data
    df_hist = pd.DataFrame()
    for m in range(total_months):
        start_d = str(list_mon_begin[m])[:10]
        end_d = str(list_mon_end[m])[:10]
        file_path = f'{response_cache_path}/{location}_{start_d}_{end_d}'
        
        try:
            if response_cache_path and os.path.exists(file_path):
                print('Reading cached data for ' + location + ': from ' + start_d + ' to ' + end_d)
                with open(file_path, 'r') as f:
                    json_data = json.load(f)
            else:
                print('Currently retrieving data for ' + location + ': from ' + start_d + ' to ' + end_d)
                url_page = 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=' + api_key + '&q=' + location + '&format=json&date=' + start_d + '&enddate=' + end_d + '&tp=' + str(frequency)
                json_page = urllib.request.urlopen(url_page, timeout=10)
                json_data = json.loads(json_page.read().decode())
                
                if response_cache_path:
                    with open(file_path, 'w') as f:
                        json.dump(json_data, f)
            
            data = json_data['data']['weather']
            # call function to extract json object
            df_this_month = extract_monthly_data(data)
            df_this_month['location'] = location
            df_hist = pd.concat([df_hist, df_this_month])
        except Exception as e:
            print('Error encountered:', e)

        time_elapsed = datetime.now() - start_time
        print('Time elapsed (hh:mm:ss.ms) {}'.format(time_elapsed))
    
    return df_hist

# %%
def extract_monthly_data(data):
    num_days = len(data)
    # initialize df_month to store return data
    df_month = pd.DataFrame()
    for i in range(num_days):
        # extract this day
        d = data[i]
        # astronomy data is the same for the whole day
        astr_df = pd.DataFrame(d['astronomy'])
        # hourly data; temperature for each hour of the day
        hourly_df = pd.DataFrame(d['hourly'])
        # this wanted_key will be duplicated and use 'ffill' to fill up the NAs
        wanted_keys = ['date', 'maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour', 'uvIndex']  # The keys you want
        subset_d = dict((k, d[k]) for k in wanted_keys if k in d)
        this_df = pd.DataFrame(subset_d, index=[0])
        df = pd.concat([this_df.reset_index(drop=True), astr_df], axis=1)
        # concat selected astonomy columns with hourly data
        df = pd.concat([df, hourly_df], axis=1)
        df = df.fillna(method='ffill')
        # make date_time columm to proper format
        # fill leading zero for hours to 4 digits (0000-2400 hr)
        df['time'] = df['time'].apply(lambda x: x.zfill(4))
        # keep only first 2 digit (00-24 hr) 
        df['time'] = df['time'].str[:2]
        # convert to pandas datetime
        df['date_time'] = pd.to_datetime(df['date'] + ' ' + df['time'])
        # keep only interested columns
        col_to_keep = ['date_time', 'maxtempC', 'mintempC', 'totalSnow_cm', 'sunHour', 'uvIndex',
                       'moon_illumination', 'moonrise', 'moonset', 'sunrise', 'sunset',
                       'DewPointC', 'FeelsLikeC', 'HeatIndexC', 'WindChillC', 'WindGustKmph',
                       'cloudcover', 'humidity', 'precipMM', 'pressure', 'tempC', 'visibility',
                       'winddirDegree', 'windspeedKmph']
        df = df[col_to_keep]
        df = df.loc[:,~df.columns.duplicated()]
        df_month = pd.concat([df_month, df])
    return (df_month)

# %%
location_list = ["bellville-south-weather", "johannesburg-weather", "lawley-south-weather", "ma-africa-weather","pretoria-weather"]
start_date = "2009-01-01"
end_date = "2021-12-31"

# Initialize lists to store data

retrieve_hist_data(api_key, location_list, start_date, end_date, frequency=24)
# Out:
# Retrieving weather data for bellville-south-weather
#
#
# Currently retrieving data for bellville-south-weather: from 2009-01-01 to 2009-01-31
# /tmp/ipykernel_99479/909374209.py:5: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
# /tmp/ipykernel_99479/909374209.py:10: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
# Time elapsed (hh:mm:ss.ms) 0:00:02.962872
# Currently retrieving data for bellville-south-weather: from 2009-02-01 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:05.352425
# Currently retrieving data for bellville-south-weather: from 2009-03-01 to 2009-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.757416
# Currently retrieving data for bellville-south-weather: from 2009-04-01 to 2009-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:09.383525
# Currently retrieving data for bellville-south-weather: from 2009-05-01 to 2009-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.185830
# Currently retrieving data for bellville-south-weather: from 2009-06-01 to 2009-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:13.218567
# Currently retrieving data for bellville-south-weather: from 2009-07-01 to 2009-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:14.789388
# Currently retrieving data for bellville-south-weather: from 2009-08-01 to 2009-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:16.968765
# Currently retrieving data for bellville-south-weather: from 2009-09-01 to 2009-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:18.367271
# Currently retrieving data for bellville-south-weather: from 2009-10-01 to 2009-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.964122
# Currently retrieving data for bellville-south-weather: from 2009-11-01 to 2009-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:21.553726
# Currently retrieving data for bellville-south-weather: from 2009-12-01 to 2009-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:22.976341
# Currently retrieving data for bellville-south-weather: from 2010-01-01 to 2010-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:24.480682
# Currently retrieving data for bellville-south-weather: from 2010-02-01 to 2010-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:25.971775
# Currently retrieving data for bellville-south-weather: from 2010-03-01 to 2010-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.583564
# Currently retrieving data for bellville-south-weather: from 2010-04-01 to 2010-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:28.972845
# Currently retrieving data for bellville-south-weather: from 2010-05-01 to 2010-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:30.569492
# Currently retrieving data for bellville-south-weather: from 2010-06-01 to 2010-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:32.280215
# Currently retrieving data for bellville-south-weather: from 2010-07-01 to 2010-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:33.862604
# Currently retrieving data for bellville-south-weather: from 2010-08-01 to 2010-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:35.299714
# Currently retrieving data for bellville-south-weather: from 2010-09-01 to 2010-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:36.384851
# Currently retrieving data for bellville-south-weather: from 2010-10-01 to 2010-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:37.976016
# Currently retrieving data for bellville-south-weather: from 2010-11-01 to 2010-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:39.828072
# Currently retrieving data for bellville-south-weather: from 2010-12-01 to 2010-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:41.169877
# Currently retrieving data for bellville-south-weather: from 2011-01-01 to 2011-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:42.699471
# Currently retrieving data for bellville-south-weather: from 2011-02-01 to 2011-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:44.512876
# Currently retrieving data for bellville-south-weather: from 2011-03-01 to 2011-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:46.202755
# Currently retrieving data for bellville-south-weather: from 2011-04-01 to 2011-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:48.103893
# Currently retrieving data for bellville-south-weather: from 2011-05-01 to 2011-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:49.818316
# Currently retrieving data for bellville-south-weather: from 2011-06-01 to 2011-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:51.527250
# Currently retrieving data for bellville-south-weather: from 2011-07-01 to 2011-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:53.315400
# Currently retrieving data for bellville-south-weather: from 2011-08-01 to 2011-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:54.678893
# Currently retrieving data for bellville-south-weather: from 2011-09-01 to 2011-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:55.994364
# Currently retrieving data for bellville-south-weather: from 2011-10-01 to 2011-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:57.744723
# Currently retrieving data for bellville-south-weather: from 2011-11-01 to 2011-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:59.376897
# Currently retrieving data for bellville-south-weather: from 2011-12-01 to 2011-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:01.131951
# Currently retrieving data for bellville-south-weather: from 2012-01-01 to 2012-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:02.753068
# Currently retrieving data for bellville-south-weather: from 2012-02-01 to 2012-02-29
# Time elapsed (hh:mm:ss.ms) 0:01:04.572978
# Currently retrieving data for bellville-south-weather: from 2012-03-01 to 2012-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:06.640805
# Currently retrieving data for bellville-south-weather: from 2012-04-01 to 2012-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:08.422241
# Currently retrieving data for bellville-south-weather: from 2012-05-01 to 2012-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:10.079139
# Currently retrieving data for bellville-south-weather: from 2012-06-01 to 2012-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:11.819839
# Currently retrieving data for bellville-south-weather: from 2012-07-01 to 2012-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:14.036926
# Currently retrieving data for bellville-south-weather: from 2012-08-01 to 2012-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:16.204841
# Currently retrieving data for bellville-south-weather: from 2012-09-01 to 2012-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:17.852359
# Currently retrieving data for bellville-south-weather: from 2012-10-01 to 2012-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:19.472346
# Currently retrieving data for bellville-south-weather: from 2012-11-01 to 2012-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:21.218780
# Currently retrieving data for bellville-south-weather: from 2012-12-01 to 2012-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:22.778163
# Currently retrieving data for bellville-south-weather: from 2013-01-01 to 2013-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:24.815396
# Currently retrieving data for bellville-south-weather: from 2013-02-01 to 2013-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:26.569616
# Currently retrieving data for bellville-south-weather: from 2013-03-01 to 2013-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:28.360368
# Currently retrieving data for bellville-south-weather: from 2013-04-01 to 2013-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:30.144151
# Currently retrieving data for bellville-south-weather: from 2013-05-01 to 2013-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:31.838255
# Currently retrieving data for bellville-south-weather: from 2013-06-01 to 2013-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:33.567020
# Currently retrieving data for bellville-south-weather: from 2013-07-01 to 2013-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:35.047836
# Currently retrieving data for bellville-south-weather: from 2013-08-01 to 2013-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:36.459493
# Currently retrieving data for bellville-south-weather: from 2013-09-01 to 2013-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:37.758789
# Currently retrieving data for bellville-south-weather: from 2013-10-01 to 2013-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:39.180257
# Currently retrieving data for bellville-south-weather: from 2013-11-01 to 2013-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:40.510659
# Currently retrieving data for bellville-south-weather: from 2013-12-01 to 2013-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:42.245068
# Currently retrieving data for bellville-south-weather: from 2014-01-01 to 2014-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:44.112008
# Currently retrieving data for bellville-south-weather: from 2014-02-01 to 2014-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:45.706598
# Currently retrieving data for bellville-south-weather: from 2014-03-01 to 2014-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:47.472324
# Currently retrieving data for bellville-south-weather: from 2014-04-01 to 2014-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:49.441488
# Currently retrieving data for bellville-south-weather: from 2014-05-01 to 2014-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:51.370465
# Currently retrieving data for bellville-south-weather: from 2014-06-01 to 2014-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:52.926999
# Currently retrieving data for bellville-south-weather: from 2014-07-01 to 2014-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:55.304808
# Currently retrieving data for bellville-south-weather: from 2014-08-01 to 2014-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:56.763446
# Currently retrieving data for bellville-south-weather: from 2014-09-01 to 2014-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:58.144306
# Currently retrieving data for bellville-south-weather: from 2014-10-01 to 2014-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:00.331607
# Currently retrieving data for bellville-south-weather: from 2014-11-01 to 2014-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:01.781234
# Currently retrieving data for bellville-south-weather: from 2014-12-01 to 2014-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:03.420190
# Currently retrieving data for bellville-south-weather: from 2015-01-01 to 2015-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:04.905899
# Currently retrieving data for bellville-south-weather: from 2015-02-01 to 2015-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:06.322911
# Currently retrieving data for bellville-south-weather: from 2015-03-01 to 2015-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:07.653700
# Currently retrieving data for bellville-south-weather: from 2015-04-01 to 2015-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:09.235480
# Currently retrieving data for bellville-south-weather: from 2015-05-01 to 2015-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:10.932559
# Currently retrieving data for bellville-south-weather: from 2015-06-01 to 2015-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:12.425576
# Currently retrieving data for bellville-south-weather: from 2015-07-01 to 2015-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:14.151003
# Currently retrieving data for bellville-south-weather: from 2015-08-01 to 2015-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:15.644946
# Currently retrieving data for bellville-south-weather: from 2015-09-01 to 2015-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:16.960853
# Currently retrieving data for bellville-south-weather: from 2015-10-01 to 2015-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:18.458403
# Currently retrieving data for bellville-south-weather: from 2015-11-01 to 2015-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:20.130177
# Currently retrieving data for bellville-south-weather: from 2015-12-01 to 2015-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:21.666251
# Currently retrieving data for bellville-south-weather: from 2016-01-01 to 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:23.400117
# Currently retrieving data for bellville-south-weather: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:02:25.586564
# Currently retrieving data for bellville-south-weather: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:27.139959
# Currently retrieving data for bellville-south-weather: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:28.701305
# Currently retrieving data for bellville-south-weather: from 2016-05-01 to 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:31.264808
# Currently retrieving data for bellville-south-weather: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:33.556744
# Currently retrieving data for bellville-south-weather: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:35.165535
# Currently retrieving data for bellville-south-weather: from 2016-08-01 to 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:37.461674
# Currently retrieving data for bellville-south-weather: from 2016-09-01 to 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:38.761444
# Currently retrieving data for bellville-south-weather: from 2016-10-01 to 2016-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:40.389951
# Currently retrieving data for bellville-south-weather: from 2016-11-01 to 2016-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:42.216395
# Currently retrieving data for bellville-south-weather: from 2016-12-01 to 2016-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:43.772135
# Currently retrieving data for bellville-south-weather: from 2017-01-01 to 2017-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:45.201829
# Currently retrieving data for bellville-south-weather: from 2017-02-01 to 2017-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:46.584110
# Currently retrieving data for bellville-south-weather: from 2017-03-01 to 2017-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:48.033581
# Currently retrieving data for bellville-south-weather: from 2017-04-01 to 2017-04-30
# Error encountered: 'weather'
# Time elapsed (hh:mm:ss.ms) 0:02:48.347351
# Currently retrieving data for bellville-south-weather: from 2017-05-01 to 2017-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:49.891886
# Currently retrieving data for bellville-south-weather: from 2017-06-01 to 2017-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:51.285324
# Currently retrieving data for bellville-south-weather: from 2017-07-01 to 2017-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:52.909411
# Currently retrieving data for bellville-south-weather: from 2017-08-01 to 2017-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:54.687143
# Currently retrieving data for bellville-south-weather: from 2017-09-01 to 2017-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:56.033515
# Currently retrieving data for bellville-south-weather: from 2017-10-01 to 2017-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:57.557593
# Currently retrieving data for bellville-south-weather: from 2017-11-01 to 2017-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:59.217334
# Currently retrieving data for bellville-south-weather: from 2017-12-01 to 2017-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:00.966305
# Currently retrieving data for bellville-south-weather: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:02.755446
# Currently retrieving data for bellville-south-weather: from 2018-02-01 to 2018-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:04.186715
# Currently retrieving data for bellville-south-weather: from 2018-03-01 to 2018-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:05.817148
# Currently retrieving data for bellville-south-weather: from 2018-04-01 to 2018-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:07.254373
# Currently retrieving data for bellville-south-weather: from 2018-05-01 to 2018-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:08.916462
# Currently retrieving data for bellville-south-weather: from 2018-06-01 to 2018-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:10.491088
# Currently retrieving data for bellville-south-weather: from 2018-07-01 to 2018-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:12.040862
# Currently retrieving data for bellville-south-weather: from 2018-08-01 to 2018-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:14.159163
# Currently retrieving data for bellville-south-weather: from 2018-09-01 to 2018-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:15.303261
# Currently retrieving data for bellville-south-weather: from 2018-10-01 to 2018-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:17.081005
# Currently retrieving data for bellville-south-weather: from 2018-11-01 to 2018-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:18.415386
# Currently retrieving data for bellville-south-weather: from 2018-12-01 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:19.807571
# Currently retrieving data for bellville-south-weather: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:21.397212
# Currently retrieving data for bellville-south-weather: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:22.908476
# Currently retrieving data for bellville-south-weather: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:24.469912
# Currently retrieving data for bellville-south-weather: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:26.029331
# Currently retrieving data for bellville-south-weather: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:27.397884
# Currently retrieving data for bellville-south-weather: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:28.885927
# Currently retrieving data for bellville-south-weather: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:30.488823
# Currently retrieving data for bellville-south-weather: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:31.996328
# Currently retrieving data for bellville-south-weather: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:33.140958
# Currently retrieving data for bellville-south-weather: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:34.806837
# Currently retrieving data for bellville-south-weather: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:36.150188
# Currently retrieving data for bellville-south-weather: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:37.772221
# Currently retrieving data for bellville-south-weather: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:39.449926
# Currently retrieving data for bellville-south-weather: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:03:40.650616
# Currently retrieving data for bellville-south-weather: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:42.388846
# Currently retrieving data for bellville-south-weather: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:44.107504
# Currently retrieving data for bellville-south-weather: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:45.705452
# Currently retrieving data for bellville-south-weather: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:46.994956
# Currently retrieving data for bellville-south-weather: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:48.415343
# Currently retrieving data for bellville-south-weather: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:49.810064
# Currently retrieving data for bellville-south-weather: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:51.170438
# Currently retrieving data for bellville-south-weather: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:52.935094
# Currently retrieving data for bellville-south-weather: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:54.581764
# Currently retrieving data for bellville-south-weather: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:56.260909
# Currently retrieving data for bellville-south-weather: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:58.195889
# Currently retrieving data for bellville-south-weather: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:59.688623
# Currently retrieving data for bellville-south-weather: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:04:01.386446
# Currently retrieving data for bellville-south-weather: from 2021-04-01 to 2021-04-30
# Time elapsed (hh:mm:ss.ms) 0:04:02.849500
# Currently retrieving data for bellville-south-weather: from 2021-05-01 to 2021-05-31
# Time elapsed (hh:mm:ss.ms) 0:04:04.309459
# Currently retrieving data for bellville-south-weather: from 2021-06-01 to 2021-06-30
# Time elapsed (hh:mm:ss.ms) 0:04:05.537605
# Currently retrieving data for bellville-south-weather: from 2021-07-01 to 2021-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:07.105608
# Currently retrieving data for bellville-south-weather: from 2021-08-01 to 2021-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:08.542586
# Currently retrieving data for bellville-south-weather: from 2021-09-01 to 2021-09-30
# Time elapsed (hh:mm:ss.ms) 0:04:11.195850
# Currently retrieving data for bellville-south-weather: from 2021-10-01 to 2021-10-31
# Time elapsed (hh:mm:ss.ms) 0:04:12.764355
# Currently retrieving data for bellville-south-weather: from 2021-11-01 to 2021-11-30
# Time elapsed (hh:mm:ss.ms) 0:04:14.073965
# Currently retrieving data for bellville-south-weather: from 2021-12-01 to 2021-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:15.472785
#
#
# export bellville-south-weather completed!
#
#
#
#
# Retrieving weather data for johannesburg-weather
#
#
# Currently retrieving data for johannesburg-weather: from 2009-01-01 to 2009-01-31
# /tmp/ipykernel_99479/909374209.py:5: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
# /tmp/ipykernel_99479/909374209.py:10: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
# Time elapsed (hh:mm:ss.ms) 0:00:02.351227
# Currently retrieving data for johannesburg-weather: from 2009-02-01 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:04.448460
# Currently retrieving data for johannesburg-weather: from 2009-03-01 to 2009-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.860313
# Currently retrieving data for johannesburg-weather: from 2009-04-01 to 2009-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:08.741488
# Currently retrieving data for johannesburg-weather: from 2009-05-01 to 2009-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.301058
# Currently retrieving data for johannesburg-weather: from 2009-06-01 to 2009-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:11.824836
# Currently retrieving data for johannesburg-weather: from 2009-07-01 to 2009-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.638914
# Currently retrieving data for johannesburg-weather: from 2009-08-01 to 2009-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:15.637584
# Currently retrieving data for johannesburg-weather: from 2009-09-01 to 2009-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:17.194282
# Currently retrieving data for johannesburg-weather: from 2009-10-01 to 2009-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.265035
# Currently retrieving data for johannesburg-weather: from 2009-11-01 to 2009-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:21.037190
# Currently retrieving data for johannesburg-weather: from 2009-12-01 to 2009-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:22.640763
# Currently retrieving data for johannesburg-weather: from 2010-01-01 to 2010-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:24.354098
# Currently retrieving data for johannesburg-weather: from 2010-02-01 to 2010-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:25.834278
# Currently retrieving data for johannesburg-weather: from 2010-03-01 to 2010-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.832464
# Currently retrieving data for johannesburg-weather: from 2010-04-01 to 2010-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:29.749148
# Currently retrieving data for johannesburg-weather: from 2010-05-01 to 2010-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:31.369339
# Currently retrieving data for johannesburg-weather: from 2010-06-01 to 2010-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:32.995811
# Currently retrieving data for johannesburg-weather: from 2010-07-01 to 2010-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:35.187863
# Currently retrieving data for johannesburg-weather: from 2010-08-01 to 2010-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:36.943426
# Currently retrieving data for johannesburg-weather: from 2010-09-01 to 2010-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:38.741917
# Currently retrieving data for johannesburg-weather: from 2010-10-01 to 2010-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:40.192138
# Currently retrieving data for johannesburg-weather: from 2010-11-01 to 2010-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:41.496971
# Currently retrieving data for johannesburg-weather: from 2010-12-01 to 2010-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:43.243343
# Currently retrieving data for johannesburg-weather: from 2011-01-01 to 2011-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:45.075570
# Currently retrieving data for johannesburg-weather: from 2011-02-01 to 2011-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:46.987333
# Currently retrieving data for johannesburg-weather: from 2011-03-01 to 2011-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:48.705026
# Currently retrieving data for johannesburg-weather: from 2011-04-01 to 2011-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:50.496056
# Currently retrieving data for johannesburg-weather: from 2011-05-01 to 2011-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:52.454996
# Currently retrieving data for johannesburg-weather: from 2011-06-01 to 2011-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:54.152275
# Currently retrieving data for johannesburg-weather: from 2011-07-01 to 2011-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:56.277008
# Currently retrieving data for johannesburg-weather: from 2011-08-01 to 2011-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:57.753421
# Currently retrieving data for johannesburg-weather: from 2011-09-01 to 2011-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:59.111200
# Currently retrieving data for johannesburg-weather: from 2011-10-01 to 2011-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:00.723156
# Currently retrieving data for johannesburg-weather: from 2011-11-01 to 2011-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:02.621347
# Currently retrieving data for johannesburg-weather: from 2011-12-01 to 2011-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:04.746908
# Currently retrieving data for johannesburg-weather: from 2012-01-01 to 2012-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:06.603613
# Currently retrieving data for johannesburg-weather: from 2012-02-01 to 2012-02-29
# Time elapsed (hh:mm:ss.ms) 0:01:08.044894
# Currently retrieving data for johannesburg-weather: from 2012-03-01 to 2012-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:09.923714
# Currently retrieving data for johannesburg-weather: from 2012-04-01 to 2012-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:11.558334
# Currently retrieving data for johannesburg-weather: from 2012-05-01 to 2012-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:13.156155
# Currently retrieving data for johannesburg-weather: from 2012-06-01 to 2012-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:14.905892
# Currently retrieving data for johannesburg-weather: from 2012-07-01 to 2012-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:16.578612
# Currently retrieving data for johannesburg-weather: from 2012-08-01 to 2012-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:18.521544
# Currently retrieving data for johannesburg-weather: from 2012-09-01 to 2012-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:21.216505
# Currently retrieving data for johannesburg-weather: from 2012-10-01 to 2012-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:22.867350
# Currently retrieving data for johannesburg-weather: from 2012-11-01 to 2012-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:25.030500
# Currently retrieving data for johannesburg-weather: from 2012-12-01 to 2012-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:27.111780
# Currently retrieving data for johannesburg-weather: from 2013-01-01 to 2013-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:29.002335
# Currently retrieving data for johannesburg-weather: from 2013-02-01 to 2013-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:30.340641
# Currently retrieving data for johannesburg-weather: from 2013-03-01 to 2013-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:32.200826
# Currently retrieving data for johannesburg-weather: from 2013-04-01 to 2013-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:34.181083
# Currently retrieving data for johannesburg-weather: from 2013-05-01 to 2013-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:36.345156
# Currently retrieving data for johannesburg-weather: from 2013-06-01 to 2013-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:37.954275
# Currently retrieving data for johannesburg-weather: from 2013-07-01 to 2013-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:39.458954
# Currently retrieving data for johannesburg-weather: from 2013-08-01 to 2013-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:41.142593
# Currently retrieving data for johannesburg-weather: from 2013-09-01 to 2013-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:42.586439
# Currently retrieving data for johannesburg-weather: from 2013-10-01 to 2013-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:44.265375
# Currently retrieving data for johannesburg-weather: from 2013-11-01 to 2013-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:46.092396
# Currently retrieving data for johannesburg-weather: from 2013-12-01 to 2013-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:47.580255
# Currently retrieving data for johannesburg-weather: from 2014-01-01 to 2014-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:49.669556
# Currently retrieving data for johannesburg-weather: from 2014-02-01 to 2014-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:51.115562
# Currently retrieving data for johannesburg-weather: from 2014-03-01 to 2014-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:52.899029
# Currently retrieving data for johannesburg-weather: from 2014-04-01 to 2014-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:54.347690
# Currently retrieving data for johannesburg-weather: from 2014-05-01 to 2014-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:56.057485
# Currently retrieving data for johannesburg-weather: from 2014-06-01 to 2014-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:57.625041
# Currently retrieving data for johannesburg-weather: from 2014-07-01 to 2014-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:59.400695
# Currently retrieving data for johannesburg-weather: from 2014-08-01 to 2014-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:01.268326
# Currently retrieving data for johannesburg-weather: from 2014-09-01 to 2014-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:02.790812
# Currently retrieving data for johannesburg-weather: from 2014-10-01 to 2014-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:04.309400
# Currently retrieving data for johannesburg-weather: from 2014-11-01 to 2014-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:05.758063
# Currently retrieving data for johannesburg-weather: from 2014-12-01 to 2014-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:07.435983
# Currently retrieving data for johannesburg-weather: from 2015-01-01 to 2015-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:09.732659
# Currently retrieving data for johannesburg-weather: from 2015-02-01 to 2015-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:11.194062
# Currently retrieving data for johannesburg-weather: from 2015-03-01 to 2015-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:13.171007
# Currently retrieving data for johannesburg-weather: from 2015-04-01 to 2015-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:14.771422
# Currently retrieving data for johannesburg-weather: from 2015-05-01 to 2015-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:16.171322
# Currently retrieving data for johannesburg-weather: from 2015-06-01 to 2015-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:17.765856
# Currently retrieving data for johannesburg-weather: from 2015-07-01 to 2015-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:19.243607
# Currently retrieving data for johannesburg-weather: from 2015-08-01 to 2015-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:21.033972
# Currently retrieving data for johannesburg-weather: from 2015-09-01 to 2015-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:22.581412
# Currently retrieving data for johannesburg-weather: from 2015-10-01 to 2015-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:24.025394
# Currently retrieving data for johannesburg-weather: from 2015-11-01 to 2015-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:25.940149
# Currently retrieving data for johannesburg-weather: from 2015-12-01 to 2015-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:27.794198
# Currently retrieving data for johannesburg-weather: from 2016-01-01 to 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:29.454984
# Currently retrieving data for johannesburg-weather: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:02:31.003516
# Currently retrieving data for johannesburg-weather: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:32.843704
# Currently retrieving data for johannesburg-weather: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:34.463128
# Currently retrieving data for johannesburg-weather: from 2016-05-01 to 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:37.867545
# Currently retrieving data for johannesburg-weather: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:39.527721
# Currently retrieving data for johannesburg-weather: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:41.389952
# Currently retrieving data for johannesburg-weather: from 2016-08-01 to 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:42.773012
# Currently retrieving data for johannesburg-weather: from 2016-09-01 to 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:43.952429
# Currently retrieving data for johannesburg-weather: from 2016-10-01 to 2016-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:45.606316
# Currently retrieving data for johannesburg-weather: from 2016-11-01 to 2016-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:47.542882
# Currently retrieving data for johannesburg-weather: from 2016-12-01 to 2016-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:49.262596
# Currently retrieving data for johannesburg-weather: from 2017-01-01 to 2017-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:51.136917
# Currently retrieving data for johannesburg-weather: from 2017-02-01 to 2017-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:52.512356
# Currently retrieving data for johannesburg-weather: from 2017-03-01 to 2017-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:54.343868
# Currently retrieving data for johannesburg-weather: from 2017-04-01 to 2017-04-30
# Error encountered: 'weather'
# Time elapsed (hh:mm:ss.ms) 0:02:55.897515
# Currently retrieving data for johannesburg-weather: from 2017-05-01 to 2017-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:57.323546
# Currently retrieving data for johannesburg-weather: from 2017-06-01 to 2017-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:58.569425
# Currently retrieving data for johannesburg-weather: from 2017-07-01 to 2017-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:00.379210
# Currently retrieving data for johannesburg-weather: from 2017-08-01 to 2017-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:01.997729
# Currently retrieving data for johannesburg-weather: from 2017-09-01 to 2017-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:03.618466
# Currently retrieving data for johannesburg-weather: from 2017-10-01 to 2017-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:05.122943
# Currently retrieving data for johannesburg-weather: from 2017-11-01 to 2017-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:06.755744
# Currently retrieving data for johannesburg-weather: from 2017-12-01 to 2017-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:08.659362
# Currently retrieving data for johannesburg-weather: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:10.105122
# Currently retrieving data for johannesburg-weather: from 2018-02-01 to 2018-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:11.414869
# Currently retrieving data for johannesburg-weather: from 2018-03-01 to 2018-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:13.771134
# Currently retrieving data for johannesburg-weather: from 2018-04-01 to 2018-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:15.355014
# Currently retrieving data for johannesburg-weather: from 2018-05-01 to 2018-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:16.966307
# Currently retrieving data for johannesburg-weather: from 2018-06-01 to 2018-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:18.426794
# Currently retrieving data for johannesburg-weather: from 2018-07-01 to 2018-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:19.962486
# Currently retrieving data for johannesburg-weather: from 2018-08-01 to 2018-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:21.492297
# Currently retrieving data for johannesburg-weather: from 2018-09-01 to 2018-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:22.921491
# Currently retrieving data for johannesburg-weather: from 2018-10-01 to 2018-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:24.419062
# Currently retrieving data for johannesburg-weather: from 2018-11-01 to 2018-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:26.130512
# Currently retrieving data for johannesburg-weather: from 2018-12-01 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:27.823265
# Currently retrieving data for johannesburg-weather: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:29.999622
# Currently retrieving data for johannesburg-weather: from 2019-02-01 to 2019-02-28
# Error encountered: HTTP Error 502: Bad Gateway
# Time elapsed (hh:mm:ss.ms) 0:03:35.550561
# Currently retrieving data for johannesburg-weather: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:38.697965
# Currently retrieving data for johannesburg-weather: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:41.288603
# Currently retrieving data for johannesburg-weather: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:43.815749
# Currently retrieving data for johannesburg-weather: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:45.454147
# Currently retrieving data for johannesburg-weather: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:47.470840
# Currently retrieving data for johannesburg-weather: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:49.079250
# Currently retrieving data for johannesburg-weather: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:50.659925
# Currently retrieving data for johannesburg-weather: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:52.557083
# Currently retrieving data for johannesburg-weather: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:54.157669
# Currently retrieving data for johannesburg-weather: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:55.699977
# Currently retrieving data for johannesburg-weather: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:57.409086
# Currently retrieving data for johannesburg-weather: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:03:58.801083
# Currently retrieving data for johannesburg-weather: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:04:00.417872
# Currently retrieving data for johannesburg-weather: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:04:02.076544
# Currently retrieving data for johannesburg-weather: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:04:03.807038
# Currently retrieving data for johannesburg-weather: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:04:05.262635
# Currently retrieving data for johannesburg-weather: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:07.107715
# Currently retrieving data for johannesburg-weather: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:08.915595
# Currently retrieving data for johannesburg-weather: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:04:10.291637
# Currently retrieving data for johannesburg-weather: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:04:11.698464
# Currently retrieving data for johannesburg-weather: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:04:13.218859
# Currently retrieving data for johannesburg-weather: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:14.919425
# Currently retrieving data for johannesburg-weather: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:04:16.764086
# Currently retrieving data for johannesburg-weather: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:04:18.214938
# Currently retrieving data for johannesburg-weather: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:04:19.719592
# Currently retrieving data for johannesburg-weather: from 2021-04-01 to 2021-04-30
# Time elapsed (hh:mm:ss.ms) 0:04:21.130914
# Currently retrieving data for johannesburg-weather: from 2021-05-01 to 2021-05-31
# Time elapsed (hh:mm:ss.ms) 0:04:22.878693
# Currently retrieving data for johannesburg-weather: from 2021-06-01 to 2021-06-30
# Time elapsed (hh:mm:ss.ms) 0:04:24.755344
# Currently retrieving data for johannesburg-weather: from 2021-07-01 to 2021-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:26.409811
# Currently retrieving data for johannesburg-weather: from 2021-08-01 to 2021-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:28.111651
# Currently retrieving data for johannesburg-weather: from 2021-09-01 to 2021-09-30
# Time elapsed (hh:mm:ss.ms) 0:04:29.749350
# Currently retrieving data for johannesburg-weather: from 2021-10-01 to 2021-10-31
# Time elapsed (hh:mm:ss.ms) 0:04:31.320657
# Currently retrieving data for johannesburg-weather: from 2021-11-01 to 2021-11-30
# Time elapsed (hh:mm:ss.ms) 0:04:33.026373
# Currently retrieving data for johannesburg-weather: from 2021-12-01 to 2021-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:34.876593
#
#
# export johannesburg-weather completed!
#
#
#
#
# Retrieving weather data for lawley-south-weather
#
#
# Currently retrieving data for lawley-south-weather: from 2009-01-01 to 2009-01-31
# /tmp/ipykernel_99479/909374209.py:5: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
# /tmp/ipykernel_99479/909374209.py:10: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
# Time elapsed (hh:mm:ss.ms) 0:00:02.436344
# Currently retrieving data for lawley-south-weather: from 2009-02-01 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:04.677842
# Currently retrieving data for lawley-south-weather: from 2009-03-01 to 2009-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.039264
# Currently retrieving data for lawley-south-weather: from 2009-04-01 to 2009-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:08.652095
# Currently retrieving data for lawley-south-weather: from 2009-05-01 to 2009-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.439415
# Currently retrieving data for lawley-south-weather: from 2009-06-01 to 2009-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:11.870815
# Currently retrieving data for lawley-south-weather: from 2009-07-01 to 2009-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.933825
# Currently retrieving data for lawley-south-weather: from 2009-08-01 to 2009-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:15.251048
# Currently retrieving data for lawley-south-weather: from 2009-09-01 to 2009-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:17.163452
# Currently retrieving data for lawley-south-weather: from 2009-10-01 to 2009-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:18.873765
# Currently retrieving data for lawley-south-weather: from 2009-11-01 to 2009-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:20.390105
# Currently retrieving data for lawley-south-weather: from 2009-12-01 to 2009-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:21.877071
# Currently retrieving data for lawley-south-weather: from 2010-01-01 to 2010-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:23.509951
# Currently retrieving data for lawley-south-weather: from 2010-02-01 to 2010-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:25.128912
# Currently retrieving data for lawley-south-weather: from 2010-03-01 to 2010-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:26.708471
# Currently retrieving data for lawley-south-weather: from 2010-04-01 to 2010-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:28.671849
# Currently retrieving data for lawley-south-weather: from 2010-05-01 to 2010-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:30.186902
# Currently retrieving data for lawley-south-weather: from 2010-06-01 to 2010-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:31.625613
# Currently retrieving data for lawley-south-weather: from 2010-07-01 to 2010-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:33.449839
# Currently retrieving data for lawley-south-weather: from 2010-08-01 to 2010-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:35.025522
# Currently retrieving data for lawley-south-weather: from 2010-09-01 to 2010-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:36.454410
# Currently retrieving data for lawley-south-weather: from 2010-10-01 to 2010-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:37.749414
# Currently retrieving data for lawley-south-weather: from 2010-11-01 to 2010-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:39.402622
# Currently retrieving data for lawley-south-weather: from 2010-12-01 to 2010-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:40.942806
# Currently retrieving data for lawley-south-weather: from 2011-01-01 to 2011-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:42.521188
# Currently retrieving data for lawley-south-weather: from 2011-02-01 to 2011-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:44.221359
# Currently retrieving data for lawley-south-weather: from 2011-03-01 to 2011-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:45.991402
# Currently retrieving data for lawley-south-weather: from 2011-04-01 to 2011-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:47.558012
# Currently retrieving data for lawley-south-weather: from 2011-05-01 to 2011-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:49.330284
# Currently retrieving data for lawley-south-weather: from 2011-06-01 to 2011-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:51.241891
# Currently retrieving data for lawley-south-weather: from 2011-07-01 to 2011-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:52.777718
# Currently retrieving data for lawley-south-weather: from 2011-08-01 to 2011-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:54.443208
# Currently retrieving data for lawley-south-weather: from 2011-09-01 to 2011-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:56.214252
# Currently retrieving data for lawley-south-weather: from 2011-10-01 to 2011-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:57.771120
# Currently retrieving data for lawley-south-weather: from 2011-11-01 to 2011-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:59.241780
# Currently retrieving data for lawley-south-weather: from 2011-12-01 to 2011-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:00.680290
# Currently retrieving data for lawley-south-weather: from 2012-01-01 to 2012-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:02.309671
# Currently retrieving data for lawley-south-weather: from 2012-02-01 to 2012-02-29
# Time elapsed (hh:mm:ss.ms) 0:01:04.022529
# Currently retrieving data for lawley-south-weather: from 2012-03-01 to 2012-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:05.826681
# Currently retrieving data for lawley-south-weather: from 2012-04-01 to 2012-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:07.596423
# Currently retrieving data for lawley-south-weather: from 2012-05-01 to 2012-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:09.527985
# Currently retrieving data for lawley-south-weather: from 2012-06-01 to 2012-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:11.017534
# Currently retrieving data for lawley-south-weather: from 2012-07-01 to 2012-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:12.795750
# Currently retrieving data for lawley-south-weather: from 2012-08-01 to 2012-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:14.297632
# Currently retrieving data for lawley-south-weather: from 2012-09-01 to 2012-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:16.000493
# Currently retrieving data for lawley-south-weather: from 2012-10-01 to 2012-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:17.517237
# Currently retrieving data for lawley-south-weather: from 2012-11-01 to 2012-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:18.895886
# Currently retrieving data for lawley-south-weather: from 2012-12-01 to 2012-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:20.785602
# Currently retrieving data for lawley-south-weather: from 2013-01-01 to 2013-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:22.574750
# Currently retrieving data for lawley-south-weather: from 2013-02-01 to 2013-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:24.552955
# Currently retrieving data for lawley-south-weather: from 2013-03-01 to 2013-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:27.148067
# Currently retrieving data for lawley-south-weather: from 2013-04-01 to 2013-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:28.769454
# Currently retrieving data for lawley-south-weather: from 2013-05-01 to 2013-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:30.498347
# Currently retrieving data for lawley-south-weather: from 2013-06-01 to 2013-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:32.172497
# Currently retrieving data for lawley-south-weather: from 2013-07-01 to 2013-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:33.500543
# Currently retrieving data for lawley-south-weather: from 2013-08-01 to 2013-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:35.227205
# Currently retrieving data for lawley-south-weather: from 2013-09-01 to 2013-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:36.752046
# Currently retrieving data for lawley-south-weather: from 2013-10-01 to 2013-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:38.408968
# Currently retrieving data for lawley-south-weather: from 2013-11-01 to 2013-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:39.711716
# ...
# Time elapsed (hh:mm:ss.ms) 0:00:42.719591
# Currently retrieving data for pretoria-weather: from 2011-01-01 to 2011-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:44.902317
# Currently retrieving data for pretoria-weather: from 2011-02-01 to 2011-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:46.579588
# Currently retrieving data for pretoria-weather: from 2011-03-01 to 2011-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:48.274874
# Currently retrieving data for pretoria-weather: from 2011-04-01 to 2011-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:50.000409
# Currently retrieving data for pretoria-weather: from 2011-05-01 to 2011-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:51.674649
# Currently retrieving data for pretoria-weather: from 2011-06-01 to 2011-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:53.372266
# Currently retrieving data for pretoria-weather: from 2011-07-01 to 2011-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:55.411181
# Currently retrieving data for pretoria-weather: from 2011-08-01 to 2011-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:57.655746
# Currently retrieving data for pretoria-weather: from 2011-09-01 to 2011-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:59.062167
# Currently retrieving data for pretoria-weather: from 2011-10-01 to 2011-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:00.737920
# Currently retrieving data for pretoria-weather: from 2011-11-01 to 2011-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:02.174665
# Currently retrieving data for pretoria-weather: from 2011-12-01 to 2011-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:03.718325
# Currently retrieving data for pretoria-weather: from 2012-01-01 to 2012-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:05.397686
# Currently retrieving data for pretoria-weather: from 2012-02-01 to 2012-02-29
# Time elapsed (hh:mm:ss.ms) 0:01:06.998559
# Currently retrieving data for pretoria-weather: from 2012-03-01 to 2012-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:08.477116
# Currently retrieving data for pretoria-weather: from 2012-04-01 to 2012-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:10.341294
# Currently retrieving data for pretoria-weather: from 2012-05-01 to 2012-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:12.014047
# Currently retrieving data for pretoria-weather: from 2012-06-01 to 2012-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:13.386155
# Currently retrieving data for pretoria-weather: from 2012-07-01 to 2012-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:14.897838
# Currently retrieving data for pretoria-weather: from 2012-08-01 to 2012-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:16.475538
# Currently retrieving data for pretoria-weather: from 2012-09-01 to 2012-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:17.914624
# Currently retrieving data for pretoria-weather: from 2012-10-01 to 2012-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:19.417671
# Currently retrieving data for pretoria-weather: from 2012-11-01 to 2012-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:20.897725
# Currently retrieving data for pretoria-weather: from 2012-12-01 to 2012-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:22.422071
# Currently retrieving data for pretoria-weather: from 2013-01-01 to 2013-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:24.401281
# Currently retrieving data for pretoria-weather: from 2013-02-01 to 2013-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:25.757595
# Currently retrieving data for pretoria-weather: from 2013-03-01 to 2013-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:27.099680
# Currently retrieving data for pretoria-weather: from 2013-04-01 to 2013-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:28.649297
# Currently retrieving data for pretoria-weather: from 2013-05-01 to 2013-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:30.500270
# Currently retrieving data for pretoria-weather: from 2013-06-01 to 2013-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:32.114182
# Currently retrieving data for pretoria-weather: from 2013-07-01 to 2013-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:33.721371
# Currently retrieving data for pretoria-weather: from 2013-08-01 to 2013-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:35.212477
# Currently retrieving data for pretoria-weather: from 2013-09-01 to 2013-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:36.599267
# Currently retrieving data for pretoria-weather: from 2013-10-01 to 2013-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:38.462502
# Currently retrieving data for pretoria-weather: from 2013-11-01 to 2013-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:39.970695
# Currently retrieving data for pretoria-weather: from 2013-12-01 to 2013-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:42.771810
# Currently retrieving data for pretoria-weather: from 2014-01-01 to 2014-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:44.387361
# Currently retrieving data for pretoria-weather: from 2014-02-01 to 2014-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:45.802889
# Currently retrieving data for pretoria-weather: from 2014-03-01 to 2014-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:47.413482
# Currently retrieving data for pretoria-weather: from 2014-04-01 to 2014-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:48.810127
# Currently retrieving data for pretoria-weather: from 2014-05-01 to 2014-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:50.663524
# Currently retrieving data for pretoria-weather: from 2014-06-01 to 2014-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:52.290291
# Currently retrieving data for pretoria-weather: from 2014-07-01 to 2014-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:53.633292
# Currently retrieving data for pretoria-weather: from 2014-08-01 to 2014-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:55.135046
# Currently retrieving data for pretoria-weather: from 2014-09-01 to 2014-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:56.601797
# Currently retrieving data for pretoria-weather: from 2014-10-01 to 2014-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:58.282279
# Currently retrieving data for pretoria-weather: from 2014-11-01 to 2014-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:59.657101
# Currently retrieving data for pretoria-weather: from 2014-12-01 to 2014-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:01.050702
# Currently retrieving data for pretoria-weather: from 2015-01-01 to 2015-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:02.440690
# Currently retrieving data for pretoria-weather: from 2015-02-01 to 2015-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:03.902734
# Currently retrieving data for pretoria-weather: from 2015-03-01 to 2015-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:05.366108
# Currently retrieving data for pretoria-weather: from 2015-04-01 to 2015-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:07.090544
# Currently retrieving data for pretoria-weather: from 2015-05-01 to 2015-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:08.818534
# Currently retrieving data for pretoria-weather: from 2015-06-01 to 2015-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:10.126232
# Currently retrieving data for pretoria-weather: from 2015-07-01 to 2015-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:11.422931
# Currently retrieving data for pretoria-weather: from 2015-08-01 to 2015-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:12.947342
# Currently retrieving data for pretoria-weather: from 2015-09-01 to 2015-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:14.343528
# Currently retrieving data for pretoria-weather: from 2015-10-01 to 2015-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:15.734063
# Currently retrieving data for pretoria-weather: from 2015-11-01 to 2015-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:17.321360
# Currently retrieving data for pretoria-weather: from 2015-12-01 to 2015-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:18.816882
# Currently retrieving data for pretoria-weather: from 2016-01-01 to 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:20.370661
# Currently retrieving data for pretoria-weather: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:02:21.865294
# Currently retrieving data for pretoria-weather: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:23.852483
# Currently retrieving data for pretoria-weather: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:25.455305
# Currently retrieving data for pretoria-weather: from 2016-05-01 to 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:27.399343
# Currently retrieving data for pretoria-weather: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:29.081465
# Currently retrieving data for pretoria-weather: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:31.050897
# Currently retrieving data for pretoria-weather: from 2016-08-01 to 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:32.751587
# Currently retrieving data for pretoria-weather: from 2016-09-01 to 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:33.989401
# Currently retrieving data for pretoria-weather: from 2016-10-01 to 2016-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:35.640607
# Currently retrieving data for pretoria-weather: from 2016-11-01 to 2016-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:37.155169
# Currently retrieving data for pretoria-weather: from 2016-12-01 to 2016-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:38.802410
# Currently retrieving data for pretoria-weather: from 2017-01-01 to 2017-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:40.503753
# Currently retrieving data for pretoria-weather: from 2017-02-01 to 2017-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:41.797085
# Currently retrieving data for pretoria-weather: from 2017-03-01 to 2017-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:43.740284
# Currently retrieving data for pretoria-weather: from 2017-04-01 to 2017-04-30
# Error encountered: 'weather'
# Time elapsed (hh:mm:ss.ms) 0:02:44.044869
# Currently retrieving data for pretoria-weather: from 2017-05-01 to 2017-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:45.565998
# Currently retrieving data for pretoria-weather: from 2017-06-01 to 2017-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:46.665417
# Currently retrieving data for pretoria-weather: from 2017-07-01 to 2017-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:48.053429
# Currently retrieving data for pretoria-weather: from 2017-08-01 to 2017-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:49.623684
# Currently retrieving data for pretoria-weather: from 2017-09-01 to 2017-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:50.834509
# Currently retrieving data for pretoria-weather: from 2017-10-01 to 2017-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:52.654130
# Currently retrieving data for pretoria-weather: from 2017-11-01 to 2017-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:54.185760
# Currently retrieving data for pretoria-weather: from 2017-12-01 to 2017-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:55.851453
# Currently retrieving data for pretoria-weather: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:57.430091
# Currently retrieving data for pretoria-weather: from 2018-02-01 to 2018-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:58.649611
# Currently retrieving data for pretoria-weather: from 2018-03-01 to 2018-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:00.205419
# Currently retrieving data for pretoria-weather: from 2018-04-01 to 2018-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:01.846653
# Currently retrieving data for pretoria-weather: from 2018-05-01 to 2018-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:03.226989
# Currently retrieving data for pretoria-weather: from 2018-06-01 to 2018-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:04.929400
# Currently retrieving data for pretoria-weather: from 2018-07-01 to 2018-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:06.657438
# Currently retrieving data for pretoria-weather: from 2018-08-01 to 2018-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:07.980393
# Currently retrieving data for pretoria-weather: from 2018-09-01 to 2018-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:09.353842
# Currently retrieving data for pretoria-weather: from 2018-10-01 to 2018-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:11.186694
# Currently retrieving data for pretoria-weather: from 2018-11-01 to 2018-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:12.699395
# Currently retrieving data for pretoria-weather: from 2018-12-01 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:14.165528
# Currently retrieving data for pretoria-weather: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:16.256289
# Currently retrieving data for pretoria-weather: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:17.707226
# Currently retrieving data for pretoria-weather: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:20.070215
# Currently retrieving data for pretoria-weather: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:21.563956
# Currently retrieving data for pretoria-weather: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:23.360350
# Currently retrieving data for pretoria-weather: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:24.721826
# Currently retrieving data for pretoria-weather: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:26.210566
# Currently retrieving data for pretoria-weather: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:27.976153
# Currently retrieving data for pretoria-weather: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:29.463639
# Currently retrieving data for pretoria-weather: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:31.105478
# Currently retrieving data for pretoria-weather: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:32.769669
# Currently retrieving data for pretoria-weather: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:34.168289
# Currently retrieving data for pretoria-weather: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:35.862941
# Currently retrieving data for pretoria-weather: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:03:37.733066
# Currently retrieving data for pretoria-weather: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:39.272521
# Currently retrieving data for pretoria-weather: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:41.085143
# Currently retrieving data for pretoria-weather: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:42.897276
# Currently retrieving data for pretoria-weather: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:44.362541
# Currently retrieving data for pretoria-weather: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:45.930529
# Currently retrieving data for pretoria-weather: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:47.569825
# Currently retrieving data for pretoria-weather: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:48.930783
# Currently retrieving data for pretoria-weather: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:50.424489
# Currently retrieving data for pretoria-weather: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:52.089525
# Currently retrieving data for pretoria-weather: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:53.594959
# Currently retrieving data for pretoria-weather: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:55.312212
# Currently retrieving data for pretoria-weather: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:56.825766
# Currently retrieving data for pretoria-weather: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:58.746679
# Currently retrieving data for pretoria-weather: from 2021-04-01 to 2021-04-30
# Time elapsed (hh:mm:ss.ms) 0:04:00.210349
# Currently retrieving data for pretoria-weather: from 2021-05-01 to 2021-05-31
# Time elapsed (hh:mm:ss.ms) 0:04:01.483807
# Currently retrieving data for pretoria-weather: from 2021-06-01 to 2021-06-30
# Time elapsed (hh:mm:ss.ms) 0:04:02.990386
# Currently retrieving data for pretoria-weather: from 2021-07-01 to 2021-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:04.717345
# Currently retrieving data for pretoria-weather: from 2021-08-01 to 2021-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:06.675067
# Currently retrieving data for pretoria-weather: from 2021-09-01 to 2021-09-30
# Time elapsed (hh:mm:ss.ms) 0:04:08.252475
# Currently retrieving data for pretoria-weather: from 2021-10-01 to 2021-10-31
# Time elapsed (hh:mm:ss.ms) 0:04:10.061845
# Currently retrieving data for pretoria-weather: from 2021-11-01 to 2021-11-30
# Time elapsed (hh:mm:ss.ms) 0:04:11.570915
# Currently retrieving data for pretoria-weather: from 2021-12-01 to 2021-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:12.975386
#
#
# export pretoria-weather completed!
# []
